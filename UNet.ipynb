# %%
import numpy as np
import pandas as pd
import nibabel as nib
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
from tensorflow.keras import layers
from tensorflow.keras.metrics import Precision, Recall
from keras_flops import get_flops

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, Input, MaxPooling2D, Dropout, concatenate, UpSampling2D, BatchNormalization, Activation, Conv2DTranspose
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
import gc

# %%
# Read and examine metadata
raw_data = pd.read_csv(r'../COVID-19 Lung CT Scan Segmentation/COVID-19 Lung CT Scan Segmentation/metadata_temp.csv')
raw_data.sample(5)
# Out:
#                                               ct_scan  \
# 7   C:\Application\Programming\Research\Lung_Segme...
# 4   C:\Application\Programming\Research\Lung_Segme...
# 12  C:\Application\Programming\Research\Lung_Segme...
# 5   C:\Application\Programming\Research\Lung_Segme...
# 0   C:\Application\Programming\Research\Lung_Segme...
#
#                                             lung_mask  \
# 7   C:\Application\Programming\Research\Lung_Segme...
# 4   C:\Application\Programming\Research\Lung_Segme...
# 12  C:\Application\Programming\Research\Lung_Segme...
# 5   C:\Application\Programming\Research\Lung_Segme...
# 0   C:\Application\Programming\Research\Lung_Segme...
#
#                                        infection_mask  \
# 7   C:\Application\Programming\Research\Lung_Segme...
# 4   C:\Application\Programming\Research\Lung_Segme...
# 12  C:\Application\Programming\Research\Lung_Segme...
# 5   C:\Application\Programming\Research\Lung_Segme...
# 0   C:\Application\Programming\Research\Lung_Segme...
#
#                               lung_and_infection_mask
# 7   C:\Application\Programming\Research\Lung_Segme...
# 4   C:\Application\Programming\Research\Lung_Segme...
# 12  C:\Application\Programming\Research\Lung_Segme...
# 5   C:\Application\Programming\Research\Lung_Segme...
# 0   C:\Application\Programming\Research\Lung_Segme...

# %%
def read_nii(filepath):
    '''
    Reads .nii file and returns pixel array
    '''
    ct_scan = nib.load(filepath)
    array   = ct_scan.get_fdata()
    array   = np.rot90(np.array(array))
    return(array)

# %%
# Read sample
sample_ct   = read_nii(raw_data.loc[1,'ct_scan'])
sample_lung = read_nii(raw_data.loc[1,'lung_mask'])
sample_infe = read_nii(raw_data.loc[1,'infection_mask'])
sample_all  = read_nii(raw_data.loc[1,'lung_and_infection_mask'])

# Examine Shape
sample_ct.shape
# Out:
# (512, 512, 200)

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,4,1)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.title('Original Image')

plt.subplot(1,4,2)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_lung[..., 150],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung Mask')

plt.subplot(1,4,3)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_infe[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Infection Mask')

plt.subplot(1,4,4)
plt.imshow(sample_ct[..., 150], cmap = 'bone')
plt.imshow(sample_all[..., 150], alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Lung and Infection Mask')
# Out:
# Text(0.5, 1.0, 'Lung and Infection Mask')

# %%
IMG_SIZE = 128
IMG_HEIGHT = IMG_SIZE
IMG_WIDTH = IMG_SIZE
IMG_CHANNELS = 1

# %%
def get_data():
    lungs_data = []
    infections_data  = []
    
    for row in range(len(raw_data)):
        lungs_image = read_nii(raw_data['ct_scan'][row])
        infection_image = read_nii(raw_data['infection_mask'][row])
        
        for slice_no in range(lungs_image.shape[2]):
            lung_slice = cv2.resize(lungs_image[..., slice_no], dsize=(IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_AREA)
            infection_slice = cv2.resize(infection_image[..., slice_no], dsize=(IMG_SIZE, IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            lungs_data.append(lung_slice[..., np.newaxis])
            infections_data.append(infection_slice[..., np.newaxis])
    return lungs_data, infections_data

# %%
data = get_data()
lungs = np.array(data[0])
infections = np.array(data[1])

# %%
fig = plt.figure(figsize = (18,15))
plt.subplot(1,2,1)
plt.imshow(lungs[451], cmap = 'bone')
plt.title('Transformed Image')

plt.subplot(1,2,2)
plt.imshow(lungs[451], cmap = 'bone')
plt.imshow(infections[451],alpha = 0.5, cmap = 'nipy_spectral')
plt.title('Transformed Infection Mask')
# Out:
# Text(0.5, 1.0, 'Transformed Infection Mask')

# %%
# Split the data into train and test sets
lung_train, lung_test, infect_train, infect_test = train_test_split(lungs, infections, test_size=0.1, shuffle=True)

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x

# %%
def Unet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    """Function to define the UNET Model"""
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
import tensorflow.keras.backend as K

def jaccard_loss(y_true, y_pred, smooth=1e-7):
    y_true = K.cast(y_true, dtype='float32')  # Cast y_true to float32
    intersection = K.sum(y_true * y_pred, axis=(1, 2, 3))
    union = K.sum(y_true, axis=(1, 2, 3)) + K.sum(y_pred, axis=(1, 2, 3)) - intersection
    jaccard = (intersection + smooth) / (union + smooth)
    return 1 - jaccard

# %%
from keras import backend as K
K.clear_session()

# Define the UNET model with TensorFlow's MeanIoU metric
input_img = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), name='img')
model = Unet(input_img, n_filters=16, dropout=0.05, batchnorm=True)
metrics = ["accuracy", 
           tf.keras.metrics.AUC(), 
           tf.keras.metrics.SensitivityAtSpecificity(0.5), 
           tf.keras.metrics.SpecificityAtSensitivity(0.5),
           tf.keras.metrics.MeanIoU(num_classes=2)]  # Use MeanIoU as the Jaccard Index metric
model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=metrics)  # Use custom Jaccard loss

gc.collect()
# Out:
# 0

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  img (InputLayer)               [(None, 128, 128, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 16  160         ['img[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 16  64         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  2320        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 16  64         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['activation_1[0][0]']
#
#  dropout (Dropout)              (None, 64, 64, 16)   0           ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 32)   4640        ['dropout[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 32)   9248        ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)  0           ['activation_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 32)   0           ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 64)   18496       ['dropout_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 64)   0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)  0           ['activation_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 64)   0           ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 128)  73856       ['dropout_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 16, 16, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 128)  147584      ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 16, 16, 128)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)   0           ['activation_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 8, 8, 128)    0           ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 256)    295168      ['dropout_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 8, 8, 256)    0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 256)    590080      ['activation_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 8, 8, 256)    0           ['batch_normalization_9[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  295040     ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'activation_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 256)  0           ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 128)  295040      ['dropout_4[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 128)  147584      ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 16, 16, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  73792       ['activation_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 128)  0           ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 64)   73792       ['dropout_5[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 64)  256         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 64)   36928       ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 64)  256         ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 64)   0           ['batch_normalization_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 32)  18464       ['activation_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 64)   0           ['concatenate_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 32)   18464       ['dropout_6[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 32)  128         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 32)   9248        ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 32)  128         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 64, 32)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 16  4624       ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 128, 128, 32  0           ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 16  4624        ['dropout_7[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 16  64         ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 16  2320        ['activation_16[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 16  64         ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 128, 128, 16  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 1)  17          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 2,164,305
# Trainable params: 2,161,361
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
# Define callbacks
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-Unet.h5', verbose=1, save_best_only=True, save_weights_only=True),
]

# %%
results = model.fit(lung_train, infect_train, batch_size=8, epochs=50, callbacks=callbacks, validation_data=(lung_test, infect_test), use_multiprocessing=True)
# Out:
# Epoch 1/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0972 - accuracy: 0.9925 - auc: 0.7648 - sensitivity_at_specificity: 0.8511 - specificity_at_sensitivity: 0.8323 - mean_io_u: 0.4967
# Epoch 1: val_loss improved from inf to 0.04023, saving model to model-Unet.h5
# 396/396 [==============================] - 32s 62ms/step - loss: 0.0972 - accuracy: 0.9925 - auc: 0.7648 - sensitivity_at_specificity: 0.8511 - specificity_at_sensitivity: 0.8323 - mean_io_u: 0.4967 - val_loss: 0.0402 - val_accuracy: 0.9937 - val_auc: 0.9418 - val_sensitivity_at_specificity: 0.9364 - val_specificity_at_sensitivity: 0.9956 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 2/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9948 - auc: 0.9642 - sensitivity_at_specificity: 0.9867 - specificity_at_sensitivity: 0.9965 - mean_io_u: 0.4967
# Epoch 2: val_loss improved from 0.04023 to 0.02060, saving model to model-Unet.h5
# 396/396 [==============================] - 24s 61ms/step - loss: 0.0264 - accuracy: 0.9948 - auc: 0.9642 - sensitivity_at_specificity: 0.9867 - specificity_at_sensitivity: 0.9965 - mean_io_u: 0.4967 - val_loss: 0.0206 - val_accuracy: 0.9950 - val_auc: 0.9610 - val_sensitivity_at_specificity: 0.9079 - val_specificity_at_sensitivity: 0.9980 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 3/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9953 - auc: 0.9848 - sensitivity_at_specificity: 0.9914 - specificity_at_sensitivity: 0.9983 - mean_io_u: 0.4967
# Epoch 3: val_loss improved from 0.02060 to 0.01755, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 63ms/step - loss: 0.0174 - accuracy: 0.9953 - auc: 0.9848 - sensitivity_at_specificity: 0.9914 - specificity_at_sensitivity: 0.9983 - mean_io_u: 0.4967 - val_loss: 0.0176 - val_accuracy: 0.9955 - val_auc: 0.9478 - val_sensitivity_at_specificity: 0.9071 - val_specificity_at_sensitivity: 0.9990 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 4/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0125 - accuracy: 0.9960 - auc: 0.9883 - sensitivity_at_specificity: 0.9839 - specificity_at_sensitivity: 0.9992 - mean_io_u: 0.4967
# Epoch 4: val_loss improved from 0.01755 to 0.01263, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 63ms/step - loss: 0.0125 - accuracy: 0.9960 - auc: 0.9883 - sensitivity_at_specificity: 0.9839 - specificity_at_sensitivity: 0.9992 - mean_io_u: 0.4967 - val_loss: 0.0126 - val_accuracy: 0.9952 - val_auc: 0.9916 - val_sensitivity_at_specificity: 0.9894 - val_specificity_at_sensitivity: 0.9993 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 5/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9963 - auc: 0.9903 - sensitivity_at_specificity: 0.9859 - specificity_at_sensitivity: 0.9994 - mean_io_u: 0.4967
# Epoch 5: val_loss improved from 0.01263 to 0.00966, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 63ms/step - loss: 0.0106 - accuracy: 0.9963 - auc: 0.9903 - sensitivity_at_specificity: 0.9859 - specificity_at_sensitivity: 0.9994 - mean_io_u: 0.4967 - val_loss: 0.0097 - val_accuracy: 0.9965 - val_auc: 0.9890 - val_sensitivity_at_specificity: 0.9817 - val_specificity_at_sensitivity: 0.9997 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 6/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 0.9968 - auc: 0.9934 - sensitivity_at_specificity: 0.9898 - specificity_at_sensitivity: 0.9996 - mean_io_u: 0.4967
# Epoch 6: val_loss improved from 0.00966 to 0.00797, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 63ms/step - loss: 0.0086 - accuracy: 0.9968 - auc: 0.9934 - sensitivity_at_specificity: 0.9898 - specificity_at_sensitivity: 0.9996 - mean_io_u: 0.4967 - val_loss: 0.0080 - val_accuracy: 0.9969 - val_auc: 0.9936 - val_sensitivity_at_specificity: 0.9894 - val_specificity_at_sensitivity: 0.9998 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 7/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.9969 - auc: 0.9923 - sensitivity_at_specificity: 0.9875 - specificity_at_sensitivity: 0.9997 - mean_io_u: 0.4967
# Epoch 7: val_loss did not improve from 0.00797
# 396/396 [==============================] - 25s 63ms/step - loss: 0.0083 - accuracy: 0.9969 - auc: 0.9923 - sensitivity_at_specificity: 0.9875 - specificity_at_sensitivity: 0.9997 - mean_io_u: 0.4967 - val_loss: 0.0096 - val_accuracy: 0.9962 - val_auc: 0.9907 - val_sensitivity_at_specificity: 0.9847 - val_specificity_at_sensitivity: 0.9997 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 8/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9972 - auc: 0.9947 - sensitivity_at_specificity: 0.9916 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967
# Epoch 8: val_loss did not improve from 0.00797
# 396/396 [==============================] - 25s 63ms/step - loss: 0.0072 - accuracy: 0.9972 - auc: 0.9947 - sensitivity_at_specificity: 0.9916 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967 - val_loss: 0.0100 - val_accuracy: 0.9967 - val_auc: 0.9861 - val_sensitivity_at_specificity: 0.9773 - val_specificity_at_sensitivity: 0.9997 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 9/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9973 - auc: 0.9938 - sensitivity_at_specificity: 0.9898 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967
# Epoch 9: val_loss improved from 0.00797 to 0.00632, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0071 - accuracy: 0.9973 - auc: 0.9938 - sensitivity_at_specificity: 0.9898 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967 - val_loss: 0.0063 - val_accuracy: 0.9976 - val_auc: 0.9969 - val_sensitivity_at_specificity: 0.9955 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 10/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9974 - auc: 0.9955 - sensitivity_at_specificity: 0.9928 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967
# Epoch 10: val_loss did not improve from 0.00632
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0065 - accuracy: 0.9974 - auc: 0.9955 - sensitivity_at_specificity: 0.9928 - specificity_at_sensitivity: 0.9998 - mean_io_u: 0.4967 - val_loss: 0.0076 - val_accuracy: 0.9970 - val_auc: 0.9953 - val_sensitivity_at_specificity: 0.9926 - val_specificity_at_sensitivity: 0.9998 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 11/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9976 - auc: 0.9963 - sensitivity_at_specificity: 0.9943 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 11: val_loss did not improve from 0.00632
# 396/396 [==============================] - 26s 64ms/step - loss: 0.0060 - accuracy: 0.9976 - auc: 0.9963 - sensitivity_at_specificity: 0.9943 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0067 - val_accuracy: 0.9972 - val_auc: 0.9961 - val_sensitivity_at_specificity: 0.9939 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 12/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9977 - auc: 0.9964 - sensitivity_at_specificity: 0.9943 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 12: val_loss improved from 0.00632 to 0.00590, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0058 - accuracy: 0.9977 - auc: 0.9964 - sensitivity_at_specificity: 0.9943 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0059 - val_accuracy: 0.9977 - val_auc: 0.9931 - val_sensitivity_at_specificity: 0.9873 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 13/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9977 - auc: 0.9965 - sensitivity_at_specificity: 0.9945 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 13: val_loss did not improve from 0.00590
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0057 - accuracy: 0.9977 - auc: 0.9965 - sensitivity_at_specificity: 0.9945 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0154 - val_accuracy: 0.9962 - val_auc: 0.9223 - val_sensitivity_at_specificity: 0.8485 - val_specificity_at_sensitivity: 0.9997 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 14/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9971 - sensitivity_at_specificity: 0.9956 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 14: val_loss did not improve from 0.00590
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0054 - accuracy: 0.9978 - auc: 0.9971 - sensitivity_at_specificity: 0.9956 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0174 - val_accuracy: 0.9937 - val_auc: 0.9557 - val_sensitivity_at_specificity: 0.9222 - val_specificity_at_sensitivity: 0.9992 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 15/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9978 - auc: 0.9966 - sensitivity_at_specificity: 0.9946 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 15: val_loss improved from 0.00590 to 0.00535, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 64ms/step - loss: 0.0055 - accuracy: 0.9978 - auc: 0.9966 - sensitivity_at_specificity: 0.9946 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0053 - val_accuracy: 0.9979 - val_auc: 0.9962 - val_sensitivity_at_specificity: 0.9936 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 16/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.9978 - auc: 0.9964 - sensitivity_at_specificity: 0.9941 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 16: val_loss improved from 0.00535 to 0.00517, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 64ms/step - loss: 0.0055 - accuracy: 0.9978 - auc: 0.9964 - sensitivity_at_specificity: 0.9941 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0052 - val_accuracy: 0.9979 - val_auc: 0.9969 - val_sensitivity_at_specificity: 0.9949 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 17/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9979 - auc: 0.9973 - sensitivity_at_specificity: 0.9958 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 17: val_loss did not improve from 0.00517
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0051 - accuracy: 0.9979 - auc: 0.9973 - sensitivity_at_specificity: 0.9958 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0079 - val_accuracy: 0.9970 - val_auc: 0.9814 - val_sensitivity_at_specificity: 0.9641 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 18/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9979 - auc: 0.9973 - sensitivity_at_specificity: 0.9958 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 18: val_loss did not improve from 0.00517
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0051 - accuracy: 0.9979 - auc: 0.9973 - sensitivity_at_specificity: 0.9958 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0052 - val_accuracy: 0.9979 - val_auc: 0.9952 - val_sensitivity_at_specificity: 0.9915 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 19/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9980 - auc: 0.9978 - sensitivity_at_specificity: 0.9966 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 19: val_loss improved from 0.00517 to 0.00500, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0048 - accuracy: 0.9980 - auc: 0.9978 - sensitivity_at_specificity: 0.9966 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0050 - val_accuracy: 0.9980 - val_auc: 0.9979 - val_sensitivity_at_specificity: 0.9968 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 20/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9981 - auc: 0.9980 - sensitivity_at_specificity: 0.9969 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 20: val_loss improved from 0.00500 to 0.00479, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 64ms/step - loss: 0.0045 - accuracy: 0.9981 - auc: 0.9980 - sensitivity_at_specificity: 0.9969 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0048 - val_accuracy: 0.9981 - val_auc: 0.9957 - val_sensitivity_at_specificity: 0.9923 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 21/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9981 - auc: 0.9978 - sensitivity_at_specificity: 0.9966 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 21: val_loss did not improve from 0.00479
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0045 - accuracy: 0.9981 - auc: 0.9978 - sensitivity_at_specificity: 0.9966 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0058 - val_accuracy: 0.9978 - val_auc: 0.9914 - val_sensitivity_at_specificity: 0.9840 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 22/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9981 - auc: 0.9978 - sensitivity_at_specificity: 0.9965 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 22: val_loss improved from 0.00479 to 0.00475, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 65ms/step - loss: 0.0045 - accuracy: 0.9981 - auc: 0.9978 - sensitivity_at_specificity: 0.9965 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0047 - val_accuracy: 0.9981 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9942 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 23/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9981 - auc: 0.9979 - sensitivity_at_specificity: 0.9968 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 23: val_loss did not improve from 0.00475
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0045 - accuracy: 0.9981 - auc: 0.9979 - sensitivity_at_specificity: 0.9968 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0050 - val_accuracy: 0.9980 - val_auc: 0.9955 - val_sensitivity_at_specificity: 0.9919 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 24/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 0.9982 - auc: 0.9979 - sensitivity_at_specificity: 0.9968 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967
# Epoch 24: val_loss did not improve from 0.00475
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0044 - accuracy: 0.9982 - auc: 0.9979 - sensitivity_at_specificity: 0.9968 - specificity_at_sensitivity: 0.9999 - mean_io_u: 0.4967 - val_loss: 0.0051 - val_accuracy: 0.9979 - val_auc: 0.9950 - val_sensitivity_at_specificity: 0.9911 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 25/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9982 - auc: 0.9983 - sensitivity_at_specificity: 0.9975 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 25: val_loss did not improve from 0.00475
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0042 - accuracy: 0.9982 - auc: 0.9983 - sensitivity_at_specificity: 0.9975 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0053 - val_accuracy: 0.9979 - val_auc: 0.9946 - val_sensitivity_at_specificity: 0.9903 - val_specificity_at_sensitivity: 0.9999 - val_mean_io_u: 0.4965 - lr: 0.0010
# Epoch 26/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9984 - auc: 0.9988 - sensitivity_at_specificity: 0.9983 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 26: val_loss improved from 0.00475 to 0.00433, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 64ms/step - loss: 0.0038 - accuracy: 0.9984 - auc: 0.9988 - sensitivity_at_specificity: 0.9983 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9982 - val_auc: 0.9970 - val_sensitivity_at_specificity: 0.9948 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-04
# Epoch 27/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9985 - auc: 0.9989 - sensitivity_at_specificity: 0.9984 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 27: val_loss improved from 0.00433 to 0.00432, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 64ms/step - loss: 0.0036 - accuracy: 0.9985 - auc: 0.9989 - sensitivity_at_specificity: 0.9984 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9982 - val_auc: 0.9964 - val_sensitivity_at_specificity: 0.9935 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-04
# Epoch 28/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9985 - auc: 0.9988 - sensitivity_at_specificity: 0.9983 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 28: val_loss did not improve from 0.00432
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0035 - accuracy: 0.9985 - auc: 0.9988 - sensitivity_at_specificity: 0.9983 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0044 - val_accuracy: 0.9982 - val_auc: 0.9961 - val_sensitivity_at_specificity: 0.9930 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-04
# Epoch 29/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9985 - auc: 0.9989 - sensitivity_at_specificity: 0.9984 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 29: val_loss improved from 0.00432 to 0.00427, saving model to model-Unet.h5
# 396/396 [==============================] - 26s 66ms/step - loss: 0.0035 - accuracy: 0.9985 - auc: 0.9989 - sensitivity_at_specificity: 0.9984 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9964 - val_sensitivity_at_specificity: 0.9935 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-04
# Epoch 30/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9985 - auc: 0.9989 - sensitivity_at_specificity: 0.9983 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 30: val_loss improved from 0.00427 to 0.00426, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0035 - accuracy: 0.9985 - auc: 0.9989 - sensitivity_at_specificity: 0.9983 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9940 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-04
# Epoch 31/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9985 - auc: 0.9990 - sensitivity_at_specificity: 0.9985 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 31: val_loss improved from 0.00426 to 0.00424, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0034 - accuracy: 0.9985 - auc: 0.9990 - sensitivity_at_specificity: 0.9985 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0042 - val_accuracy: 0.9983 - val_auc: 0.9967 - val_sensitivity_at_specificity: 0.9942 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-04
# Epoch 32/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9986 - auc: 0.9989 - sensitivity_at_specificity: 0.9983 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 32: val_loss improved from 0.00424 to 0.00423, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0034 - accuracy: 0.9986 - auc: 0.9989 - sensitivity_at_specificity: 0.9983 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0042 - val_accuracy: 0.9983 - val_auc: 0.9965 - val_sensitivity_at_specificity: 0.9938 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 33/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 33: val_loss improved from 0.00423 to 0.00423, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0034 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0042 - val_accuracy: 0.9983 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9939 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 34/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9985 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 34: val_loss improved from 0.00423 to 0.00423, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0034 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9985 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0042 - val_accuracy: 0.9983 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9940 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 35/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 35: val_loss improved from 0.00423 to 0.00421, saving model to model-Unet.h5
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0033 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0042 - val_accuracy: 0.9983 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9939 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 36/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 36: val_loss did not improve from 0.00421
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0034 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0042 - val_accuracy: 0.9983 - val_auc: 0.9964 - val_sensitivity_at_specificity: 0.9935 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 37/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9985 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 37: val_loss did not improve from 0.00421
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0034 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9985 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0042 - val_accuracy: 0.9983 - val_auc: 0.9965 - val_sensitivity_at_specificity: 0.9936 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 38/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9985 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 38: val_loss did not improve from 0.00421
# 396/396 [==============================] - 25s 63ms/step - loss: 0.0034 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9985 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0042 - val_accuracy: 0.9983 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9938 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 39/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9985 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 39: val_loss did not improve from 0.00421
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0033 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9985 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0042 - val_accuracy: 0.9983 - val_auc: 0.9965 - val_sensitivity_at_specificity: 0.9937 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 40/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9985 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 40: val_loss did not improve from 0.00421
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0033 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9985 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0042 - val_accuracy: 0.9983 - val_auc: 0.9966 - val_sensitivity_at_specificity: 0.9939 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 41/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9984 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 41: val_loss did not improve from 0.00421
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0033 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9984 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0043 - val_accuracy: 0.9983 - val_auc: 0.9963 - val_sensitivity_at_specificity: 0.9934 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 42/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9986 - auc: 0.9991 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 42: val_loss did not improve from 0.00421
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0033 - accuracy: 0.9986 - auc: 0.9991 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0042 - val_accuracy: 0.9983 - val_auc: 0.9965 - val_sensitivity_at_specificity: 0.9938 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 43/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 43: val_loss did not improve from 0.00421
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0033 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0042 - val_accuracy: 0.9983 - val_auc: 0.9964 - val_sensitivity_at_specificity: 0.9936 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 44/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 44: val_loss did not improve from 0.00421
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0033 - accuracy: 0.9986 - auc: 0.9990 - sensitivity_at_specificity: 0.9986 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0042 - val_accuracy: 0.9983 - val_auc: 0.9965 - val_sensitivity_at_specificity: 0.9937 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 45/50
# 396/396 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9986 - auc: 0.9988 - sensitivity_at_specificity: 0.9982 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967
# Epoch 45: val_loss did not improve from 0.00421
# 396/396 [==============================] - 25s 64ms/step - loss: 0.0034 - accuracy: 0.9986 - auc: 0.9988 - sensitivity_at_specificity: 0.9982 - specificity_at_sensitivity: 1.0000 - mean_io_u: 0.4967 - val_loss: 0.0042 - val_accuracy: 0.9983 - val_auc: 0.9963 - val_sensitivity_at_specificity: 0.9934 - val_specificity_at_sensitivity: 1.0000 - val_mean_io_u: 0.4965 - lr: 1.0000e-05
# Epoch 45: early stopping

# %%
df_result = pd.DataFrame(results.history)
df_result.sort_values('val_loss', ascending=True, inplace = True)
df_result
# Out:
#         loss  accuracy       auc  sensitivity_at_specificity  \
# 34  0.003350  0.998585  0.999030                    0.998577
# 38  0.003342  0.998587  0.998996                    0.998506
# 41  0.003318  0.998593  0.999070                    0.998648
# 43  0.003313  0.998603  0.999023                    0.998550
# 37  0.003358  0.998578  0.998987                    0.998494
# 39  0.003329  0.998592  0.999000                    0.998509
# 33  0.003363  0.998583  0.998998                    0.998518
# 36  0.003351  0.998586  0.998997                    0.998512
# 44  0.003350  0.998592  0.998827                    0.998167
# 32  0.003357  0.998584  0.999045                    0.998609
# 42  0.003322  0.998598  0.999037                    0.998583
# 31  0.003385  0.998569  0.998902                    0.998329
# 30  0.003441  0.998546  0.998973                    0.998492
# 35  0.003353  0.998584  0.999022                    0.998562
# 40  0.003336  0.998591  0.998950                    0.998412
# 29  0.003469  0.998536  0.998873                    0.998300
# 28  0.003503  0.998519  0.998901                    0.998368
# 26  0.003577  0.998487  0.998924                    0.998438
# 25  0.003769  0.998416  0.998809                    0.998273
# 27  0.003537  0.998503  0.998840                    0.998256
# 21  0.004478  0.998145  0.997786                    0.996485
# 19  0.004525  0.998112  0.997987                    0.996912
# 18  0.004751  0.998035  0.997776                    0.996588
# 22  0.004473  0.998139  0.997932                    0.996786
# 23  0.004417  0.998170  0.997942                    0.996783
# 15  0.005546  0.997762  0.996352                    0.994105
# 17  0.005062  0.997928  0.997326                    0.995819
# 24  0.004233  0.998233  0.998319                    0.997463
# 14  0.005451  0.997783  0.996624                    0.994603
# 20  0.004532  0.998116  0.997817                    0.996574
# 11  0.005825  0.997670  0.996395                    0.994320
# 8   0.007117  0.997260  0.993766                    0.989782
# 10  0.006031  0.997582  0.996323                    0.994270
# 9   0.006509  0.997424  0.995480                    0.992832
# 16  0.005146  0.997879  0.997286                    0.995781
# 5   0.008576  0.996840  0.993356                    0.989844
# 6   0.008275  0.996910  0.992258                    0.987514
# 4   0.010635  0.996307  0.990315                    0.985864
# 7   0.007154  0.997249  0.994690                    0.991609
# 3   0.012523  0.995959  0.988264                    0.983914
# 12  0.005717  0.997704  0.996498                    0.994479
# 13  0.005372  0.997809  0.997125                    0.995563
# 2   0.017353  0.995302  0.984789                    0.991435
# 1   0.026403  0.994829  0.964241                    0.986662
# 0   0.097156  0.992503  0.764781                    0.851115
#
#     specificity_at_sensitivity  mean_io_u  val_loss  val_accuracy   val_auc  \
# 34                    0.999984    0.49673  0.004211      0.998284  0.996611
# 38                    0.999986    0.49673  0.004214      0.998282  0.996490
# 41                    0.999987    0.49673  0.004218      0.998281  0.996538
# 43                    0.999985    0.49673  0.004220      0.998278  0.996489
# 37                    0.999983    0.49673  0.004221      0.998281  0.996562
# 39                    0.999987    0.49673  0.004223      0.998276  0.996622
# 33                    0.999984    0.49673  0.004226      0.998272  0.996632
# 36                    0.999985    0.49673  0.004227      0.998282  0.996463
# 44                    0.999987    0.49673  0.004228      0.998278  0.996330
# 32                    0.999984    0.49673  0.004229      0.998274  0.996595
# 42                    0.999987    0.49673  0.004231      0.998273  0.996439
# 31                    0.999984    0.49673  0.004234      0.998269  0.996545
# 30                    0.999983    0.49673  0.004241      0.998264  0.996725
# 35                    0.999984    0.49673  0.004243      0.998270  0.996411
# 40                    0.999987    0.49673  0.004259      0.998268  0.996337
# 29                    0.999984    0.49673  0.004261      0.998256  0.996622
# 28                    0.999984    0.49673  0.004272      0.998260  0.996403
# 26                    0.999982    0.49673  0.004323      0.998233  0.996405
# 25                    0.999974    0.49673  0.004334      0.998218  0.997017
# 27                    0.999982    0.49673  0.004378      0.998225  0.996108
# 21                    0.999954    0.49673  0.004745      0.998081  0.996626
# 19                    0.999950    0.49673  0.004788      0.998079  0.995678
# 18                    0.999937    0.49673  0.005000      0.997957  0.997899
# 22                    0.999947    0.49673  0.005020      0.997970  0.995451
# 23                    0.999949    0.49673  0.005120      0.997948  0.995026
# 15                    0.999887    0.49673  0.005173      0.997905  0.996896
# 17                    0.999917    0.49673  0.005210      0.997875  0.995205
# 24                    0.999958    0.49673  0.005329      0.997887  0.994606
# 14                    0.999896    0.49673  0.005349      0.997864  0.996216
# 20                    0.999948    0.49673  0.005776      0.997823  0.991412
# 11                    0.999876    0.49673  0.005901      0.997701  0.993077
# 8                     0.999789    0.49673  0.006318      0.997602  0.996936
# 10                    0.999852    0.49673  0.006712      0.997230  0.996108
# 9                     0.999812    0.49673  0.007567      0.997021  0.995262
# 16                    0.999917    0.49673  0.007937      0.996979  0.981366
# 5                     0.999641    0.49673  0.007975      0.996890  0.993558
# 6                     0.999664    0.49673  0.009618      0.996202  0.990711
# 4                     0.999429    0.49673  0.009658      0.996547  0.988983
# 7                     0.999778    0.49673  0.010019      0.996684  0.986067
# 3                     0.999181    0.49673  0.012634      0.995162  0.991594
# 12                    0.999886    0.49673  0.015383      0.996215  0.922269
# 13                    0.999898    0.49673  0.017373      0.993733  0.955746
# 2                     0.998304    0.49673  0.017553      0.995535  0.947805
# 1                     0.996495    0.49673  0.020604      0.994998  0.961047
# 0                     0.832278    0.49673  0.040235      0.993706  0.941798
#
#     val_sensitivity_at_specificity  val_specificity_at_sensitivity  \
# 34                        0.993916                        0.999972
# 38                        0.993672                        0.999972
# 41                        0.993770                        0.999972
# 43                        0.993672                        0.999972
# 37                        0.993818                        0.999970
# 39                        0.993941                        0.999970
# 33                        0.993965                        0.999973
# 36                        0.993623                        0.999972
# 44                        0.993354                        0.999974
# 32                        0.993892                        0.999974
# 42                        0.993574                        0.999972
# 31                        0.993794                        0.999975
# 30                        0.994160                        0.999974
# 35                        0.993525                        0.999973
# 40                        0.993379                        0.999974
# 29                        0.993965                        0.999971
# 28                        0.993525                        0.999974
# 26                        0.993550                        0.999971
# 25                        0.994796                        0.999972
# 27                        0.992963                        0.999967
# 21                        0.994160                        0.999954
# 19                        0.992255                        0.999955
# 18                        0.996824                        0.999948
# 22                        0.991888                        0.999948
# 23                        0.991082                        0.999956
# 15                        0.994893                        0.999952
# 17                        0.991473                        0.999931
# 24                        0.990324                        0.999933
# 14                        0.993599                        0.999918
# 20                        0.984021                        0.999945
# 11                        0.987344                        0.999934
# 8                         0.995504                        0.999879
# 10                        0.993916                        0.999899
# 9                         0.992572                        0.999822
# 16                        0.964083                        0.999865
# 5                         0.989445                        0.999777
# 6                         0.984680                        0.999671
# 4                         0.981651                        0.999686
# 7                         0.977302                        0.999693
# 3                         0.989396                        0.999262
# 12                        0.848514                        0.999662
# 13                        0.922229                        0.999230
# 2                         0.907105                        0.999039
# 1                         0.907936                        0.998016
# 0                         0.936449                        0.995568
#
#     val_mean_io_u       lr
# 34       0.496452  0.00001
# 38       0.496452  0.00001
# 41       0.496452  0.00001
# 43       0.496452  0.00001
# 37       0.496452  0.00001
# 39       0.496452  0.00001
# 33       0.496452  0.00001
# 36       0.496452  0.00001
# 44       0.496452  0.00001
# 32       0.496452  0.00001
# 42       0.496452  0.00001
# 31       0.496452  0.00001
# 30       0.496452  0.00010
# 35       0.496452  0.00001
# 40       0.496452  0.00001
# 29       0.496452  0.00010
# 28       0.496452  0.00010
# 26       0.496452  0.00010
# 25       0.496452  0.00010
# 27       0.496452  0.00010
# 21       0.496452  0.00100
# 19       0.496452  0.00100
# 18       0.496452  0.00100
# 22       0.496452  0.00100
# 23       0.496452  0.00100
# 15       0.496452  0.00100
# 17       0.496452  0.00100
# 24       0.496452  0.00100
# 14       0.496452  0.00100
# 20       0.496452  0.00100
# 11       0.496452  0.00100
# 8        0.496452  0.00100
# 10       0.496452  0.00100
# 9        0.496452  0.00100
# 16       0.496452  0.00100
# 5        0.496452  0.00100
# 6        0.496452  0.00100
# 4        0.496452  0.00100
# 7        0.496452  0.00100
# 3        0.496452  0.00100
# 12       0.496452  0.00100
# 13       0.496452  0.00100
# 2        0.496452  0.00100
# 1        0.496452  0.00100
# 0        0.496452  0.00100

# %%
model.save("UNet.h5")

# %%
plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot(np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

plt.figure(figsize = (15,6))
plt.title("Learning curve")
plt.plot(results.history["accuracy"], label="Accuracy")
plt.plot(results.history["val_accuracy"], label="val_Accuracy")
plt.plot(np.argmax(results.history["val_accuracy"]), np.max(results.history["val_accuracy"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend();

# %%
# Calculate metrics
predicted = model.predict(lung_test)

# Flatten the predicted and true masks
predicted_flat = np.round(predicted.flatten())
infect_test_flat = infect_test.flatten()

# %%
# Calculate metrics for training data
train_predicted = model.predict(lung_train)

# Flatten the predicted and true masks
train_predicted_flat = np.round(train_predicted.flatten())
infect_train_flat = infect_train.flatten()

# Calculate precision and recall for training data
train_precision = Precision()
train_recall = Recall()
train_precision.update_state(infect_train_flat, train_predicted_flat)
train_recall.update_state(infect_train_flat, train_predicted_flat)

# Calculate F1 score for training data
train_f1_score = 2 * (train_precision.result() * train_recall.result()) / (train_precision.result() + train_recall.result())

# Calculate accuracy for training data
train_accuracy = np.mean(train_predicted_flat == infect_train_flat)

# Calculate metrics for testing data
test_predicted = model.predict(lung_test)

# Flatten the predicted and true masks for testing data
test_predicted_flat = np.round(test_predicted.flatten())
infect_test_flat = infect_test.flatten()

# Calculate precision and recall for testing data
test_precision = Precision()
test_recall = Recall()
test_precision.update_state(infect_test_flat, test_predicted_flat)
test_recall.update_state(infect_test_flat, test_predicted_flat)

# Calculate F1 score for testing data
test_f1_score = 2 * (test_precision.result() * test_recall.result()) / (test_precision.result() + test_recall.result())

# Calculate accuracy for testing data
test_accuracy = np.mean(test_predicted_flat == infect_test_flat)

# Calculate parameters
total_parameters = np.sum([tf.keras.backend.count_params(w) for w in model.trainable_weights])

# Calculate FLOPs
flops = get_flops(model, batch_size=1)  # Assuming batch_size = 1

# Print the metrics for training data
print("Training Metrics:")
print("Precision: ", train_precision.result().numpy())
print("Recall: ", train_recall.result().numpy())
print("F1 Score: ", train_f1_score.numpy())
print("Accuracy: ", train_accuracy)

# Print the metrics for testing data
print("\nTesting Metrics:")
print("Precision: ", test_precision.result().numpy())
print("Recall: ", test_recall.result().numpy())
print("F1 Score: ", test_f1_score.numpy())
print("Accuracy: ", test_accuracy)

# Print the other metrics
print("\nTotal Parameters: ", total_parameters)
print("FLOPs: ", flops)
# Out:
# WARNING:tensorflow:From c:\Users\kaush\anaconda3\envs\TensorflowEnv\lib\site-packages\tensorflow\python\ops\nn_ops.py:5214: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.tensor_shape_from_node_def_name`
# Training Metrics:
# Precision:  0.8973433
# Recall:  0.89063865
# F1 Score:  0.89397836
# Accuracy:  0.9986185786700008
#
# Testing Metrics:
# Precision:  0.88348097
# Recall:  0.8723857
# F1 Score:  0.8778983
# Accuracy:  0.9982778375799005
#
# Total Parameters:  2161361
# FLOPs:  1597694592

# %%
with tf.device("CPU"):
    # Calculate Jaccard Index (MeanIoU) for training data
    train_iou = tf.keras.metrics.MeanIoU(num_classes=2)
    train_iou.update_state(infect_train_flat, train_predicted_flat)
    train_mean_iou = train_iou.result().numpy()

    # Calculate Jaccard Index (MeanIoU) for testing data
    test_iou = tf.keras.metrics.MeanIoU(num_classes=2)
    test_iou.update_state(infect_test_flat, test_predicted_flat)
    test_mean_iou = test_iou.result().numpy()

    # Print the Jaccard Index (MeanIoU) for training and testing data
    print("Training Jaccard Index (MeanIoU): ", train_mean_iou)
    print("Testing Jaccard Index (MeanIoU): ", test_mean_iou)
# Out:
# Training Jaccard Index (MeanIoU):  0.9020136
# Testing Jaccard Index (MeanIoU):  0.89031833

# %%
# Plot accuracy
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.title('Accuracy vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot loss
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('Loss vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
# Make predictions
predicted = model.predict(lung_test)
# Out:
# 11/11 [==============================] - 2s 220ms/step

# %%
# Make predictions and visualize
img_num = 8
predicted = model.predict(lung_test)

# Visualize results
fig = plt.figure(figsize=(18, 15))
plt.subplot(1, 3, 1)
plt.imshow(lung_test[img_num], cmap='bone')
plt.title('Original lung')

plt.subplot(1, 3, 2)
plt.imshow(lung_test[img_num], cmap='bone')
plt.imshow(infect_test[img_num][..., 0], alpha=0.5, cmap="nipy_spectral")
plt.title('Original infection mask')

plt.subplot(1, 3, 3)
plt.imshow(lung_test[img_num], cmap='bone')
plt.imshow(predicted[img_num], alpha=0.5, cmap="nipy_spectral")
plt.title('Predicted infection mask')
# Out:
# 11/11 [==============================] - 3s 240ms/step
# Text(0.5, 1.0, 'Predicted infection mask')

# %%
# Plot Jaccard Index (MeanIoU)
plt.plot(results.history['mean_io_u'])
plt.plot(results.history['val_mean_io_u'])
plt.title('MeanIoU (Jaccard Index) vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('MeanIoU (Jaccard Index)')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
